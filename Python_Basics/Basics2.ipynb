# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
    
    
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
    
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
    
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
    
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
m2=100
m2=100
m2=100
r=6.371e6
    
f=G*(m1*vvm1)/(r**2)
f=G*(m1*vvm1)/(r**2)
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
    
f=G*(m1*vvm1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
G=6.674e-11
m1=5.972e24
m2=100
r=6.371e6
f=G*(m1*m1)/(r**2)
print(f)
# Out:
# 5.864224529997691e+25

# %%
a=10
b=10.5
c="physics"print(type(a))
print(type(b))
print(type(a))
print(type(b))
print(type(a))
print(type(b))
print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
a=10
b=1print(typrint(type(a))
print(type(b))pe(a))
print(type(b))0.5
c="physicsprint(type(a))
print(type(b))"

print(type(c))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#restaurant
Pizza=1*20
Cola=2*5
Water=2*1.5
Total=Pizza+Cola+Water
Tax=4.95
Total_Cost=Total+Tax

# %%
#okpodk
