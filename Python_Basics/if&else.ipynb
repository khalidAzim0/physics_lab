# %%
print(f'================================\nWelcome to $$ EXCHANGE STORE $$\n================================')
a=input('Exchange From : (USD ,EUR ,SAR)')
b=float(input('How Muth?'))
c=input('Exchange To : (USD ,EUR ,SAR)')
if a=='USD' and c=='USD':
    print(f"\nyou will give {b} USD,and you will take {(b)}USD")
elif a=='USD' and c=='EUR':  
    print(f"\nyou will give {b} USD,and you will take {(b)*0.99}EUR")
elif a=='USD' and c=='SAR':
    print(f"\nyou will give {b} USD,and you will take {(b)*3.75}SAR")
elif a=='EUR' and c=='EUR':
    print(f"\nyou will give {b} UER,and you will take {(b)b}UER")
elif a=='EUR' and c=='USA':
    print(f"\nyou will give {b} UER,and you will take {(b)/0.99}USD")
elif a=='EUR' and c=='SAR':
    print(f"\nyou will give {b} UER,and you will take {(b)/0.99*3.75}SAR")
elif a=='SAR' and c=='SAR':
    print(f"\nyou will give {b} SAR,and you will take {(b)}SAR")
elif a=='SAR' and c=='USD':
    print(f"\nyou will give {b} SAR,and you will take {(b)/3.75}USD")
elif a=='SAR' and c=='EUR':
    print(f"\nyou will give {b} SAR,and you will take {(b)/3.75*0.99}EUR")
else:
    print("\nincorrect input")
# Out:
# ...
# Welcome to $$ EXCHANGE STORE $$
# ...
# Exchange From : (USD ,EUR ,SAR) SAR
# How Muth? 1000
# Exchange To : (USD ,EUR ,SAR) EUR
# you will give 1000SAR,and you will take 264.0EUR
