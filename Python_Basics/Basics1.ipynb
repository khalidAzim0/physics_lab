# %%
#Basic python code
a="khalid azim"
b=25
c=180.1
d=True

print(f"My name is {a.upper()},my age is {b},my tall{c},and everything is {d}")
# Out:
# My name is KHALID AZIM,my age is 25,my tall180.1,and everything is True

# %%
#Data Type_Mehtods and 
a=input("please enter yore name:")
b=input("How old are you?")
c=input("How tall are you?")
d=input("How weight are you?")
print(f"==================== \n Welcome,{a.title()} \n you will live until {2025-int(b)} and you will be {int(c)/int(d)*int(b)+10} years old")
